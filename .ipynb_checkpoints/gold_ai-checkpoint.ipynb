# %% [markdown]
# #Installing yahoo finance Library

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\sarthakp\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (4.0.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\sarthakp\anaconda3\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\sarthakp\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\sarthakp\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sarthakp\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sarthakp\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\sarthakp\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sarthakp\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sarthakp\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sarthakp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sarthakp\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarthakp\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarthakp\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\SarthakP\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\SarthakP\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\SarthakP\anaconda3\Lib\site-packages)

# %%
#importing gold data till date 


import yfinance as yf

gold = yf.download("GC=F", start="2000-01-01")

print(gold.head())

# Save to CSV
gold.to_csv("gold_data.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open Volume
# Ticker            GC=F        GC=F        GC=F        GC=F   GC=F
# Date
# 2000-08-30  273.899994  273.899994  273.899994  273.899994      0
# 2000-08-31  278.299988  278.299988  274.799988  274.799988      0
# 2000-09-01  277.000000  277.000000  277.000000  277.000000      0
# 2000-09-05  275.799988  275.799988  275.799988  275.799988      2
# 2000-09-06  274.200012  274.200012  274.200012  274.200012      0

# %%
gold.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gold.shape()
#
# TypeError: 'tuple' object is not callable

# %%
gold.shape
# Out:
# (6417, 5)

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6417 entries, 2000-08-30 to 2026-03-27
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, GC=F)   6417 non-null   float64
#  1   (High, GC=F)    6417 non-null   float64
#  2   (Low, GC=F)     6417 non-null   float64
#  3   (Open, GC=F)    6417 non-null   float64
#  4   (Volume, GC=F)  6417 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 300.8 KB

# %%
usd_inr = yf.download("INR=X", start="2000-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
usd_inr = head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 usd_inr = head()
#
# NameError: name 'head' is not defined

# %%
print(usd_inr.head())
# Out:
# Price           Close       High        Low       Open Volume
# Ticker          INR=X      INR=X      INR=X      INR=X  INR=X
# Date
# 2003-12-01  45.709999  45.728001  45.615002  45.709000      0
# 2003-12-02  45.629002  45.719002  45.560001  45.709000      0
# 2003-12-03  45.549999  45.655998  45.474998  45.632000      0
# 2003-12-04  45.548000  45.612999  45.519001  45.548000      0
# 2003-12-05  45.449001  45.566002  45.449001  45.549999      0

# %%
#we used here Featured Engineering
# Step 1: Take only the 'Close' column from gold dataset
# (We only care about closing price, not Open/High/Low for now)
data = gold[['Close']].copy()

# Step 2: Rename column 'Close' → 'Gold_Price_USD'
# This makes it clear that this is gold price in USD
data.rename(columns={'Close': 'Gold_Price_USD'}, inplace=True)

# Step 3: Add USD/INR exchange rate into same dataframe
# We align by date automatically (because both datasets use Date index)
data['USD_INR'] = usd_inr['Close']

# Step 4: Print first few rows to verify everything worked
print(data.head())
# Out:
# Price      Gold_Price_USD USD_INR
# Ticker               GC=F
# Date
# 2000-08-30     273.899994     NaN
# 2000-08-31     278.299988     NaN
# 2000-09-01     277.000000     NaN
# 2000-09-05     275.799988     NaN
# 2000-09-06     274.200012     NaN

# %%
features = data[['GOLD_PRICE_USD', 'USD_INR']]
target = data [['Gold_Price_INR']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 features = data[['GOLD_PRICE_USD', 'USD_INR']]
#       2 target = data [['Gold_Price_INR']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2782, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2779 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2780     indexer = self._get_indexer_level_0(keyarr)
# -> 2782     self._raise_if_missing(key, indexer, axis_name)
#    2783     return self[indexer], indexer
#    2785 return super()._get_indexer_strict(key, axis_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2800, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2798 cmask = check == -1
#    2799 if cmask.any():
# -> 2800     raise KeyError(f"{keyarr[cmask]} not in index")
#    2801 # We get here when levels still contain values which are not
#    2802 # actually in Index anymore
#    2803 raise KeyError(f"{keyarr} not in index")
#
# KeyError: "['GOLD_PRICE_USD'] not in index"

# %%
features = data[['Gold_Price_USD', 'USD_INR']]
target = data['Gold_Price_INR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gold_Price_INR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 features = data[['Gold_Price_USD', 'USD_INR']]
# ----> 2 target = data['Gold_Price_INR']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4112, in DataFrame.__getitem__(self, key)
#    4110 if is_single_key:
#    4111     if self.columns.nlevels > 1:
# -> 4112         return self._getitem_multilevel(key)
#    4113     indexer = self.columns.get_loc(key)
#    4114     if is_integer(indexer):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4170, in DataFrame._getitem_multilevel(self, key)
#    4168 def _getitem_multilevel(self, key):
#    4169     # self.columns is a MultiIndex
# -> 4170     loc = self.columns.get_loc(key)
#    4171     if isinstance(loc, (slice, np.ndarray)):
#    4172         new_columns = self.columns[loc]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:3059, in MultiIndex.get_loc(self, key)
#    3056     return mask
#    3058 if not isinstance(key, tuple):
# -> 3059     loc = self._get_level_indexer(key, level=0)
#    3060     return _maybe_to_slice(loc)
#    3062 keylen = len(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:3410, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3407         return slice(i, j, step)
#    3409 else:
# -> 3410     idx = self._get_loc_single_level_index(level_index, key)
#    3412     if level > 0 or self._lexsort_depth == 0:
#    3413         # Desired level is not sorted
#    3414         if isinstance(idx, slice):
#    3415             # test_get_loc_partial_timestamp_multiindex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2999, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2997     return -1
#    2998 else:
# -> 2999     return level_index.get_loc(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Gold_Price_INR'

# %%
data['Gold_Price_INR'] = data['Gold_Price_USD'] * data['USD_INR']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26092\440382297.py in ?()
# ----> 1 data['Gold_Price_INR'] = data['Gold_Price_USD'] * data['USD_INR']
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4308             self._setitem_frame(key, value)
#    4309         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4310             self._setitem_array(key, value)
#    4311         elif isinstance(value, DataFrame):
# -> 4312             self._set_item_frame_value(key, value)
#    4313         elif (
#    4314             is_list_like(value)
#    4315             and not self.columns.is_unique
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4466
#    4467             return self.isetitem(locs, value)
#    4468
#    4469         if len(value.columns) > 1:
# -> 4470             raise ValueError(
#    4471                 "Cannot set a DataFrame with multiple columns to the single "
#    4472                 f"column {key}"
#    4473             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column Gold_Price_INR

# %%
gold_close = gold['Close']
usd_inr_close = usd_inr['Close']

# %%
data = gold_close.to_frame(name='Gold_Price_USD')

data['USD_INR'] = usd_inr_close
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26092\4270383166.py in ?()
# ----> 1 data = gold_close.to_frame(name='Gold_Price_USD')
#       2
#       3 data['USD_INR'] = usd_inr_close
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
print(gold.columns)
# Out:
# MultiIndex([( 'Close', 'GC=F'),
#             (  'High', 'GC=F'),
#             (   'Low', 'GC=F'),
#             (  'Open', 'GC=F'),
#             ('Volume', 'GC=F')],
#            names=['Price', 'Ticker'])

# %%
gold_close = gold['Close'].iloc[:, 0]
usd_inr_close = usd_inr['Close'].iloc[:, 0]

# %%
data = gold_close.to_frame(name='Gold_Price_USD')

data['USD_INR'] = usd_inr_close

# %%
data = data.dropna()

data['Gold_Price_INR'] = data['Gold_Price_USD'] * data['USD_INR']

# %%
print(data.head())
# Out:
#             Gold_Price_USD    USD_INR  Gold_Price_INR
# Date
# 2003-12-01      402.700012  45.709999    18407.417189
# 2003-12-02      403.700012  45.629002    18420.428510
# 2003-12-03      403.899994  45.549999    18397.644414
# 2003-12-04      403.299988  45.548000    18369.507979
# 2003-12-05      406.399994  45.449001    18470.473856

# %%
# Step 1: Import required libraries (yfinance, pandas, numpy, etc.)

# Step 2: Download historical data
# - Gold price (GC=F) → global gold price in USD
# - USD/INR (INR=X) → exchange rate

# Step 3: Extract closing prices
# - Handle MultiIndex issue using .iloc[:, 0]
# - Convert data into clean single-column Series

# Step 4: Create a new dataframe
# - Add Gold_Price_USD column
# - Add USD_INR column

# Step 5: Align both datasets by date
# - Pandas automatically aligns using Date index

# Step 6: Remove missing values
# - Drop NaN values caused by mismatched market days

# Step 7: Create Indian gold price
# - Gold_Price_INR = Gold_Price_USD * USD_INR

# Step 8: Define ML inputs and target
# - Features (X): Gold_Price_USD, USD_INR
# - Target (y): Gold_Price_INR

# Step 9: Normalize data using MinMaxScaler
# - Scale values between 0 and 1 for neural network

# Step 10: Create sequences for time-series model
# - Use last 60 days data → predict next day price

# Step 11: Convert sequences into numpy arrays
# - X shape: (samples, 60, features)
# - y shape: (samples,)

# Step 12: Split dataset into training and testing sets
# - 80% training, 20% testing

# %%
#Importing LSTM library 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 2
#       1 #Importing LSTM library
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import LSTM, Dense, Dropout
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
#Importing LSTM library 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Import model structure (Sequential = layers stacked one after another)
model = Sequential()

# -----------------------------
# First LSTM Layer
# -----------------------------

# LSTM(units=50):
# → 50 neurons (memory cells) that learn patterns from time-series data

# return_sequences=True:
# → VERY IMPORTANT
# → This tells LSTM to pass the full sequence to the next LSTM layer
# → Required because we are stacking another LSTM layer after this

# input_shape=(X_train.shape[1], X_train.shape[2]):
# → Defines input format:
#    X_train.shape[1] = number of time steps (e.g., 60 days)
#    X_train.shape[2] = number of features (e.g., 2 → Gold + USD/INR)

model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))

# Dropout(0.2):
# → Prevents overfitting (model memorizing instead of learning)
# → Randomly drops 20% of neurons during training
# → Helps model generalize better

model.add(Dropout(0.2))

# -----------------------------
# Second LSTM Layer
# -----------------------------

# LSTM(50):
# → Another layer to learn deeper patterns
# → return_sequences=False (default)
# → Means this layer outputs only final result (not full sequence)

model.add(LSTM(50))

# Again dropout for regularization
model.add(Dropout(0.2))

# -----------------------------
# Output Layer
# -----------------------------

# Dense(1):
# → Fully connected layer
# → Outputs a single value → predicted gold price (INR)

model.add(Dense(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 21
#       2 model = Sequential()
#       4 # -----------------------------
#       5 # First LSTM Layer
#       6 # -----------------------------
#    (...)     18 #    X_train.shape[1] = number of time steps (e.g., 60 days)
#      19 #    X_train.shape[2] = number of features (e.g., 2 → Gold + USD/INR)
# ---> 21 model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
#      23 # Dropout(0.2):
#      24 # → Prevents overfitting (model memorizing instead of learning)
#      25 # → Randomly drops 20% of neurons during training
#      26 # → Helps model generalize better
#      28 model.add(Dropout(0.2))
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(data[['Gold_Price_USD', 'USD_INR', 'Gold_Price_INR']])

# %%
import numpy as np

X = []
y = []

sequence_length = 60

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i, :-1])  # features
    y.append(scaled_data[i, -1])  # target

X = np.array(X)
y = np.array(y)

# %%
split = int(0.8 * len(X))

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
print(X_train.shape)
# Out:
# (4412, 60, 2)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 predictions = model.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\sequential.py:172, in Sequential.build(self, input_shape)
#     170     return
#     171 if not self._layers:
# --> 172     raise ValueError(
#     173         f"Sequential model {self.name} cannot be built because it has "
#     174         "no layers. Call `model.add(layer)`."
#     175     )
#     176 if isinstance(self._layers[0], InputLayer):
#     177     if self._layers[0].batch_shape != input_shape:
#
# ValueError: Sequential model sequential cannot be built because it has no layers. Call `model.add(layer)`.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
# Out:
# C:\Users\SarthakP\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 6.0494e-04
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.9349e-04
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.4722e-04
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.3830e-04
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.0689e-04
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 9.2199e-05
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 9.0157e-05
# Epoch 8/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 8.3291e-05
# Epoch 9/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 8.8283e-05
# Epoch 10/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 7.9833e-05

# %%
predictions = model.predict(X_test)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
import numpy as np

dummy = np.zeros((len(predictions), 3))
dummy[:, -1] = predictions[:, 0]

predicted_prices = scaler.inverse_transform(dummy)[:, -1]

# %%
dummy_actual = np.zeros((len(y_test), 3))
dummy_actual[:, -1] = y_test

actual_prices = scaler.inverse_transform(dummy_actual)[:, -1]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(actual_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.legend()
plt.title("Gold Price Prediction (INR)")
plt.show()

# %%
#Upgrade 1: Add Moving Averages
data['MA10'] = data['Gold_Price_INR'].rolling(10).mean()
data['MA50'] = data['Gold_Price_INR'].rolling(50).mean()

# %%
#Upgrade 2: Add Daily Returns
data['Returns'] = data['Gold_Price_INR'].pct_change()

# %%
#Upgrade 3: Drop NaN again
data = data.dropna()

# %%
#Upgrade 4: Update features
features = data[['Gold_Price_USD', 'USD_INR', 'MA10', 'MA50', 'Returns']]
target = data['Gold_Price_INR']

# %%
epochs = 20

# %%
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(actual_prices, predicted_prices))
print("RMSE:", rmse)
# Out:
# RMSE: 16409.58247858538

# %%
import numpy as np

X = []
y = []

sequence_length = 60

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i, :-1])  # features
    y.append(scaled_data[i, -1])  # target

X = np.array(X)
y = np.array(y)

# %%
split = int(0.8 * len(X))

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
# Out:
# C:\Users\SarthakP\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - loss: 8.3806e-04
# Epoch 2/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 2.2177e-04
# Epoch 3/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.7297e-04
# Epoch 4/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.5266e-04
# Epoch 5/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.1802e-04
# Epoch 6/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.1198e-04
# Epoch 7/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 9.0730e-05
# Epoch 8/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 9.6528e-05
# Epoch 9/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 8.8289e-05
# Epoch 10/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 7.8584e-05
# Epoch 11/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 7.7613e-05
# Epoch 12/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 6.3078e-05
# Epoch 13/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 6.5790e-05
# Epoch 14/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 6.0351e-05
# Epoch 15/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 6.2892e-05
# Epoch 16/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 5.5650e-05
# Epoch 17/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 5.5658e-05
# Epoch 18/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 5.6233e-05
# Epoch 19/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 5.8326e-05
# Epoch 20/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 5.3439e-05

# %%
predictions = model.predict(X_test)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# %%
features_scaled = feature_scaler.fit_transform(features)

target_scaled = target_scaler.fit_transform(target.values.reshape(-1, 1))

# %%
scaled_data = np.hstack((features_scaled, target_scaled))

# %%
predicted_prices = target_scaler.inverse_transform(predictions)

# %%
actual_prices = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

# Actual prices (real data)
plt.plot(actual_prices, label='Actual Price')

# Predicted prices (your AI)
plt.plot(predicted_prices, label='Predicted Price')

# Labels and title
plt.title("Gold Price Prediction (INR)")
plt.xlabel("Time (Days)")
plt.ylabel("Price (INR)")

plt.legend()
plt.show()

# %%
signals = []

for i in range(len(predicted_prices)):
    if predicted_prices[i] > actual_prices[i]:
        signals.append("BUY")
    else:
        signals.append("SELL")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

# Plot actual price
plt.plot(actual_prices, label='Actual Price')

# Plot BUY signals
for i in range(len(signals)):
    if signals[i] == "BUY":
        plt.scatter(i, actual_prices[i], marker='^')

# Plot SELL signals
for i in range(len(signals)):
    if signals[i] == "SELL":
        plt.scatter(i, actual_prices[i], marker='v')

plt.title("Gold Price + Trading Signals")
plt.xlabel("Time (Days)")
plt.ylabel("Price (INR)")
plt.legend()
plt.show()

# %%
profit = 0
position = None  # None / "BUY"

for i in range(len(signals)-1):

    if signals[i] == "BUY" and position is None:
        buy_price = actual_prices[i]
        position = "BUY"

    elif signals[i] == "SELL" and position == "BUY":
        sell_price = actual_prices[i]
        profit += (sell_price - buy_price)
        position = None

print("Total Profit:", profit)
# Out:
# Total Profit: [104028.64200439]

# %%
trades = signals.count("BUY")
print("Total trades:", trades)
# Out:
# Total trades: 476

# %%
if trades > 0:
    print("Average profit per trade:", profit / trades)
# Out:
# Average profit per trade: [218.54756724]

# %%
#Add threshold (reduce noise)
signals = []

for i in range(len(predicted_prices)):
    if predicted_prices[i] > actual_prices[i] * 1.01:
        signals.append("BUY")
    elif predicted_prices[i] < actual_prices[i] * 0.99:
        signals.append("SELL")
    else:
        signals.append("HOLD")

# %%
# Moving averages (already done but keep)
data['MA10'] = data['Gold_Price_INR'].rolling(10).mean()
data['MA50'] = data['Gold_Price_INR'].rolling(50).mean()

# Exponential Moving Average (more responsive)
data['EMA10'] = data['Gold_Price_INR'].ewm(span=10).mean()

# Volatility (risk measure)
data['Volatility'] = data['Gold_Price_INR'].rolling(10).std()

# Momentum
data['Momentum'] = data['Gold_Price_INR'] - data['Gold_Price_INR'].shift(10)

# RSI (VERY IMPORTANT indicator)
delta = data['Gold_Price_INR'].diff()
gain = (delta.where(delta > 0, 0)).rolling(14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(14).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Drop NaN
data = data.dropna()

# %%
features = data[['Gold_Price_USD', 'USD_INR', 'MA10', 'MA50', 'EMA10', 'Volatility', 'Momentum', 'RSI']]
target = data['Gold_Price_INR']

# %%
feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

features_scaled = feature_scaler.fit_transform(features)
target_scaled = target_scaler.fit_transform(target.values.reshape(-1,1))

scaled_data = np.hstack((features_scaled, target_scaled))

# %%
sequence_length = 90  # increased from 60

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input

model = Sequential()

# Input layer (NEW - fixes warning)
model.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# LSTM layers
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(50))
model.add(Dropout(0.2))

# Output
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 7.6616e-04
# Epoch 2/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 2.3764e-04
# Epoch 3/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 1.7016e-04
# Epoch 4/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 1.5328e-04
# Epoch 5/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 1.4504e-04
# Epoch 6/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 1.0665e-04
# Epoch 7/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 1.0613e-04
# Epoch 8/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 9.3718e-05
# Epoch 9/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 9.6172e-05
# Epoch 10/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 8.4968e-05
# Epoch 11/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 7.2982e-05
# Epoch 12/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 7.6234e-05
# Epoch 13/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 7.9447e-05
# Epoch 14/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 7.4448e-05
# Epoch 15/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 6.9197e-05
# Epoch 16/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 6.4915e-05
# Epoch 17/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 6.3934e-05
# Epoch 18/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 6.7184e-05
# Epoch 19/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 6.4468e-05
# Epoch 20/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 7.6641e-05
# Epoch 21/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 6.5465e-05
# Epoch 22/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 7.3129e-05
# Epoch 23/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 7.6392e-05
# Epoch 24/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 6.0248e-05
# Epoch 25/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.9026e-05
# Epoch 26/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.8123e-05
# Epoch 27/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 6.0032e-05
# Epoch 28/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 6.4518e-05
# Epoch 29/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 5.4271e-05
# Epoch 30/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 5.4243e-05

# %%
predictions = model.predict(X_test)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step

# %%
predicted_prices = target_scaler.inverse_transform(predictions)
actual_prices = target_scaler.inverse_transform(y_test.reshape(-1,1))

# %%
import matplotlib.pyplot as plt

# Create a large figure (for better visibility)
plt.figure(figsize=(12,6))

# Plot actual prices (ground truth)
# This is what REALLY happened in market
plt.plot(actual_prices, label='Actual Price')

# Plot predicted prices (AI output)
# This is what your model predicted
plt.plot(predicted_prices, label='Predicted Price')

# Title explains what graph is about
plt.title("Gold Price Prediction (Advanced Model)")

# X-axis = time steps (days)
plt.xlabel("Time (Days)")

# Y-axis = price in INR
plt.ylabel("Price (INR)")

# Show legend (labels)
plt.legend()

# Display graph
plt.show()

# %%
predicted_prices = np.clip(
    predicted_prices,
    actual_prices * 0.95,
    actual_prices * 1.05
)

# %%
initial_balance = 100000  # ₹1 lakh
balance = initial_balance

position = None
buy_price = 0

equity_curve = []  # tracks portfolio value over time

# %% [markdown]
# You start with ₹100,000
# Follow AI signals
# Buy / Sell gold
# Track profit over time

# %%
signals = []

for i in range(len(predicted_prices)):
    if predicted_prices[i] > actual_prices[i] * 1.01:
        signals.append("BUY")
    elif predicted_prices[i] < actual_prices[i] * 0.99:
        signals.append("SELL")
    else:
        signals.append("HOLD")

# %%
for i in range(len(signals)):

    price = actual_prices[i]

    # BUY condition
    if signals[i] == "BUY" and position is None:
        position = "BUY"
        buy_price = price

    # SELL condition
    elif signals[i] == "SELL" and position == "BUY":
        profit = price - buy_price
        balance += profit
        position = None

    # Track equity (portfolio value)
    if position == "BUY":
        equity = balance + (price - buy_price)
    else:
        equity = balance

    equity_curve.append(equity)

# %%
print("Initial Balance:", initial_balance)
print("Final Balance:", balance)
print("Total Profit:", balance - initial_balance)
# Out:
# Initial Balance: 100000
# Final Balance: [118906.99713545]
# Total Profit: [18906.99713545]

# %%
stop_loss_percent = 0.02  # 2%

for i in range(len(signals)):

    price = actual_prices[i]

    if position == "BUY":
        # Stop loss trigger
        if price < buy_price * (1 - stop_loss_percent):
            balance += (price - buy_price)
            position = None

    # BUY
    if signals[i] == "BUY" and position is None:
        position = "BUY"
        buy_price = price

    # SELL
    elif signals[i] == "SELL" and position == "BUY":
        balance += (price - buy_price)
        position = None

    # Equity tracking
    if position == "BUY":
        equity = balance + (price - buy_price)
    else:
        equity = balance

    equity_curve.append(equity)

# %%
equity_curve = []
balance = initial_balance
position = None
buy_price = 0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(equity_curve)
plt.title("Equity Curve (Portfolio Growth)")
plt.xlabel("Time")
plt.ylabel("Balance (INR)")
plt.show()

# %%
for i in range(len(signals)):

    price = actual_prices[i]

    # Stop loss
    if position == "BUY":
        if price < buy_price * 0.98:
            balance += (price - buy_price)
            position = None

    # BUY
    if signals[i] == "BUY" and position is None:
        position = "BUY"
        buy_price = price

    # SELL
    elif signals[i] == "SELL" and position == "BUY":
        balance += (price - buy_price)
        position = None

    # Track equity
    if position == "BUY":
        equity = balance + (price - buy_price)
    else:
        equity = balance

    equity_curve.append(equity)

# %%
plt.figure(figsize=(12,6))
plt.plot(equity_curve)
plt.title("Equity Curve (Portfolio Growth)")
plt.xlabel("Time")
plt.ylabel("Balance (INR)")
plt.show()

# %%
initial_balance = 100000
balance = initial_balance

position = None
buy_price = 0
quantity = 0

equity_curve = []

transaction_cost = 0.001  # 0.1%
stop_loss = 0.02  # 2%

for i in range(len(signals)):

    price = actual_prices[i]

    # STOP LOSS
    if position == "BUY":
        if price < buy_price * (1 - stop_loss):
            balance = quantity * price
            quantity = 0
            position = None

    # BUY (use full capital)
    if signals[i] == "BUY" and position is None:
        quantity = balance / price
        balance = 0
        buy_price = price
        position = "BUY"

    # SELL
    elif signals[i] == "SELL" and position == "BUY":
        balance = quantity * price
        balance -= balance * transaction_cost  # brokerage
        quantity = 0
        position = None

    # Equity tracking
    if position == "BUY":
        equity = quantity * price
    else:
        equity = balance

    equity_curve.append(equity)

# %%
print("Final Balance:", equity_curve[-1])
print("Total Profit:", equity_curve[-1] - initial_balance)
# Out:
# Final Balance: [319344.28557933]
# Total Profit: [219344.28557933]

# %%
plt.figure(figsize=(12,6))
plt.plot(equity_curve)
plt.title("Realistic Equity Curve")
plt.xlabel("Time")
plt.ylabel("Portfolio Value (INR)")
plt.show()

# %%
total_return = (equity_curve[-1] - initial_balance) / initial_balance * 100
print("Total Return (%):", total_return)
# Out:
# Total Return (%): [219.34428558]

# %%
import numpy as np

equity_array = np.array(equity_curve)

peak = equity_array[0]
max_drawdown = 0

for value in equity_array:
    if value > peak:
        peak = value
    drawdown = (peak - value) / peak
    if drawdown > max_drawdown:
        max_drawdown = drawdown

print("Max Drawdown (%):", max_drawdown * 100)
# Out:
# Max Drawdown (%): [16.20045415]

# %%
wins = 0
losses = 0

for i in range(1, len(equity_curve)):
    if equity_curve[i] > equity_curve[i-1]:
        wins += 1
    else:
        losses += 1

win_rate = wins / (wins + losses) * 100
print("Win Rate (%):", win_rate)
# Out:
# Win Rate (%): 53.81125226860254

# %%
drawdowns = []

peak = equity_array[0]

for value in equity_array:
    if value > peak:
        peak = value
    drawdowns.append((peak - value) / peak)

plt.figure(figsize=(12,4))
plt.plot(drawdowns)
plt.title("Drawdown Over Time")
plt.show()

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)

with open("feature_scaler.pkl", "wb") as f:
    pickle.dump(feature_scaler, f)

with open("target_scaler.pkl", "wb") as f:
    pickle.dump(target_scaler, f)

# %%
features = data[['Gold_Price_USD','USD_INR','MA10','MA50','EMA10','Volatility','Momentum','RSI']]
target = data['Gold_Price_INR']

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

features_scaled = feature_scaler.fit_transform(features)
target_scaled = target_scaler.fit_transform(target.values.reshape(-1,1))

scaled_data = np.hstack((features_scaled, target_scaled))

# %%
sequence_length = 90

# %%
X = []
y = []

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i, :-1])  # 8 features
    y.append(scaled_data[i, -1])

X = np.array(X)
y = np.array(y)

# %%
input_shape=(X_train.shape[1], X_train.shape[2])

# %%
model.fit(X_train, y_train, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 6.3831e-05
# Epoch 2/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 6.0080e-05
# Epoch 3/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 7.0817e-05
# Epoch 4/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.7521e-05
# Epoch 5/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.2997e-05
# Epoch 6/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.9264e-05
# Epoch 7/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.9315e-05
# Epoch 8/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.8217e-05
# Epoch 9/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 6.0399e-05
# Epoch 10/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 5.6876e-05
# Epoch 11/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.7567e-05
# Epoch 12/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 6.2203e-05
# Epoch 13/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.9039e-05
# Epoch 14/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 6.1380e-05
# Epoch 15/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.9831e-05
# Epoch 16/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.8673e-05
# Epoch 17/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.8004e-05
# Epoch 18/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 5.9711e-05
# Epoch 19/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.1551e-05
# Epoch 20/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.5509e-05
# Epoch 21/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.1183e-05
# Epoch 22/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.8092e-05
# Epoch 23/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 5.5310e-05
# Epoch 24/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.1623e-05
# Epoch 25/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - loss: 5.4572e-05
# Epoch 26/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 4.9595e-05
# Epoch 27/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.5510e-05
# Epoch 28/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.6869e-05
# Epoch 29/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 5.1744e-05
# Epoch 30/30
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 6.0820e-05

# %%
import pickle
import os

print("Saving in:", os.getcwd())

pickle.dump(model, open("C:/Users/SarthakP/gold_price_ai/model.pkl", "wb"))
pickle.dump(feature_scaler, open("C:/Users/SarthakP/gold_price_ai/feature_scaler.pkl", "wb"))
pickle.dump(target_scaler, open("C:/Users/SarthakP/gold_price_ai/target_scaler.pkl", "wb"))
# Out:
# Saving in: C:\Users\SarthakP\gold_price_ai

# %%
print(X.shape)
# Out:
# (5387, 90, 8)
